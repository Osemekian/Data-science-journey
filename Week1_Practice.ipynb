# %% [markdown]
# CREATING VARIABLES

# %%
name ="Precious"
profession ="Medical Laboratory Science"


print(name)
print(profession)
# Out:
# Precious
# Medical Laboratory Science

# %%
patient_age=25
blood_glucose= 3.5
packed_cell_volume="28%"


print(patient_age)
print(blood_glucose)
print(packed_cell_volume)
# Out:
# 25
# 3.5
# 28%

# %%
CREATING DICTIONARIES

# %%
patient_record= {"patient":"Precious", "patient_age": 25, "blood_pressure":"120/81mmHg", "PCV":"28%","blood_glucose":3.5}

print(patient_record)
# Out:
# {'patient': 'Precious', 'patient_age': 25, 'blood_pressure': '120/81mmHg', 'PCV': '28%', 'blood_glucose': 3.5}

# %%
patient_name = "Patient A"
glucose = 5.6
cholesterol = 4.1


print(patient_name)
print(glucose)
print(cholesterol)
# Out:
# Patient A
# 5.6
# 4.1

# %%
lab_results = {"TSH": 2.5,"Total_T3": 1.4,"Total_T4": 8.2}

print(lab_results)
# Out:
# {'TSH': 2.5, 'Total_T3': 1.4, 'Total_T4': 8.2}

# %%
CREATING LISTS, ACCESSING ELEMENTS, MODIFYING ELEMENTS(ADDING ITEMS, REMOVING ITEMS), SLICING LIST.

# %%
patient_id= ['P001','p002', 'p003','p004','p005','p006','p007','p008', 'p009','p010']
age= ['32', '25', '17','56','45','51', '28', '37','40','3']
sex= ['male','female','female','female','male','male','female','female','male','female']
blood_group= ['A+','B+','O+','O+','O+','B+','A-','A+','O+','B-']

print(patient_id[:3])
print(patient_id[1:])
# Out:
# ['P001', 'p002', 'p003']
# ['p002', 'p003', 'p004', 'p005', 'p006', 'p007', 'p008', 'p009', 'p010']

# %%
print(patient_id[2],age[2],sex[2],blood_group[2])
print(patient_id[-1],age[-1],sex[-1],blood_group[-1])
# Out:
# p003 17 female O+
# p010 3 female B-

# %%
print(patient_id[:5])
print(age[1])
# Out:
# ['P001', 'p002', 'p003', 'p004', 'p005']
# 25

# %%
MODIFYING ELEMENT

# %%
#Replace Items

sex= ['male','female','female','female','male','male','female','female','male','female']
sex[5]='female'
print(sex)

age= ['32', '25', '17','56','45','51', '28', '37','40','3']
age[-2]="22"
print(age)
# Out:
# ['male', 'female', 'female', 'female', 'male', 'female', 'female', 'female', 'male', 'female']
# ['32', '25', '17', '56', '45', '51', '28', '37', '22', '3']

# %%
#Remove Items

blood_group= ['A+','B+','O+','O+','O+','B+','A-','A+','O+','B-']
blood_group[-2:]= ['B-']
print(blood_group)


age= ['32', '25', '17','56','45','51', '28', '37','40','3']
age [0]='42'
print(age)

sex= ['male','female','female','female','male','male','female','female','male','female']
sex[5]='boy'
print(sex)
# Out:
# ['A+', 'B+', 'O+', 'O+', 'O+', 'B+', 'A-', 'A+', 'B-']
# ['42', '25', '17', '56', '45', '51', '28', '37', '40', '3']
# ['male', 'female', 'female', 'female', 'male', 'boy', 'female', 'female', 'male', 'female']

# %%
tests=['fasting blood sugar','full blood count','fasting lipid profile','esr','eucr','mp','stool mcs','urine mcs','urinalysis','genotype']
tests.remove('esr')
print(tests)

tests.pop(2)
print(tests)
# Out:
# ['fasting blood sugar', 'full blood count', 'fasting lipid profile', 'eucr', 'mp', 'stool mcs', 'urine mcs', 'urinalysis', 'genotype']
# ['fasting blood sugar', 'full blood count', 'eucr', 'mp', 'stool mcs', 'urine mcs', 'urinalysis', 'genotype']

# %% [markdown]
# ANALYSIS WITH LIST

# %%
patient_id= ['P001','p002', 'p003','p004','p005','p006','p007','p008', 'p009','p010']
age= ['32', '25', '17','56','45','51', '28', '37','40','3']
sex= ['male','female','female','female','male','male','female','female','male','female']
blood_group= ['A+','B+','O+','O+','O+','B+','A-','A+','O+','B-']
tests=['fasting blood sugar','full blood count','fasting lipid profile','esr','eucr','mp','stool mcs','urine mcs','urinalysis','genotype']

patient_data = list(zip(patient_id, age, sex, blood_group))
print(patient_data)
# Out:
# [('P001', '32', 'male', 'A+'), ('p002', '25', 'female', 'B+'), ('p003', '17', 'female', 'O+'), ('p004', '56', 'female', 'O+'), ('p005', '45', 'male', 'O+'), ('p006', '51', 'male', 'B+'), ('p007', '28', 'female', 'A-'), ('p008', '37', 'female', 'A+'), ('p009', '40', 'male', 'O+'), ('p010', '3', 'female', 'B-')]

# %%
patient_data = list(zip(patient_id, age, sex, tests))
print(patient_data)
# Out:
# [('P001', '32', 'male', 'fasting blood sugar'), ('p002', '25', 'female', 'full blood count'), ('p003', '17', 'female', 'fasting lipid profile'), ('p004', '56', 'female', 'esr'), ('p005', '45', 'male', 'eucr'), ('p006', '51', 'male', 'mp'), ('p007', '28', 'female', 'stool mcs'), ('p008', '37', 'female', 'urine mcs'), ('p009', '40', 'male', 'urinalysis'), ('p010', '3', 'female', 'genotype')]

# %% [markdown]
# DICTIONARY EXERCISE

# %%
patient1={'patient_id':'p001', 'age':'24','sex':'male','malaria_result':'negative','HIV_result':'negative','haemoglobin':'11.8'}
patient2={'patient_id':'p002', 'age':'38','sex':'female','malaria_result':'+','HIV_result':'negative','haemoglobin':'9.5'}
patient3={'patient_id':'p003', 'age':'18','sex':'male','malaria_result':'negative','HIV_result':'positive','haemoglobin':'6.8'}


print('patient_id:',patient1['patient_id'])
print('patient_id:',patient2['patient_id'])
print('patient_id:',patient1['patient_id'],patient2['patient_id'],patient3['patient_id'])
print(patient1)
# Out:
# patient_id: p001
# patient_id: p002
# patient_id: p001 p002 p003
# {'patient_id': 'p001', 'age': '24', 'sex': 'male', 'malaria_result': 'negative', 'HIV_result': 'negative', 'haemoglobin': '11.8'}

# %%
print('patient_id:',patient1['patient_id'])
print('age:',patient1['age'])
print('sex:',patient1['sex'])
print('malaria_result:',patient1['malaria_result'])
print('HIV_result:',patient1['HIV_result'])



print('patient_id:',patient2['patient_id'])
print('age:',patient2['age'])
print('sex:',patient2['sex'])
print('malaria_result:',patient2['malaria_result'])
print('HIV_result:',patient2['HIV_result'])



print('patient_id:',patient3['patient_id'])
print('age:',patient3['age'])
print('sex:',patient3['sex'])
print('malaria_result:',patient3['malaria_result'])
print('HIV_result:',patient3['HIV_result'])
# Out:
# patient_id: p001
# age: 24
# sex: male
# malaria_result: negative
# HIV_result: negative
# patient_id: p002
# age: 38
# sex: female
# malaria_result: +
# HIV_result: negative
# patient_id: p003
# age: 18
# sex: male
# malaria_result: negative
# HIV_result: positive

# %%
patient_data = list(zip(patient_id, age, sex, blood_group))
print(patient_data)

# %% [markdown]
# CONDITIONAL STATEMENTS

# %%
haemoglobin= 11.0
if haemoglobin < 11.0:
    print('Anaemic')
else:
    print('Normal')
# Out:
# Normal

# %%
haemoglobin= 9.2
if haemoglobin < 11.0:
    print('Anaemic')
else:
    print('Normal')
# Out:
# Anaemic

# %%
patient1={'patient_id':'p001', 'age':'24','sex':'male','malaria_result':'negative','HIV_result':'negative','haemoglobin':'11.8'}
patient2={'patient_id':'p002', 'age':'38','sex':'female','malaria_result':'+','HIV_result':'negative','haemoglobin':'9.5'}
patient3={'patient_id':'p003', 'age':'18','sex':'male','malaria_result':'negative','HIV_result':'positive','haemoglobin':'6.8'}

print(patient1.items())

print(patient2.items())

print(patient3.items())

print(patient1.keys())
# Out:
# dict_items([('patient_id', 'p001'), ('age', '24'), ('sex', 'male'), ('malaria_result', 'negative'), ('HIV_result', 'negative'), ('haemoglobin', '11.8')])
# dict_items([('patient_id', 'p002'), ('age', '38'), ('sex', 'female'), ('malaria_result', '+'), ('HIV_result', 'negative'), ('haemoglobin', '9.5')])
# dict_items([('patient_id', 'p003'), ('age', '18'), ('sex', 'male'), ('malaria_result', 'negative'), ('HIV_result', 'positive'), ('haemoglobin', '6.8')])
# dict_keys(['patient_id', 'age', 'sex', 'malaria_result', 'HIV_result', 'haemoglobin'])

# %%
patient2={'patient_id':'p002', 'age':'38','sex':'female','malaria_result':'+','HIV_result':'negative','haemoglobin':'9.5'}
patient2.update(age=47)
patient2

patient2.update(malaria_result= '++', HIV_result = 'positive')
patient2
# Out:
# {'patient_id': 'p002',
#  'age': 47,
#  'sex': 'female',
#  'malaria_result': '++',
#  'HIV_result': 'positive',
#  'haemoglobin': '9.5'}

# %%
patient1={'patient_id':'p001', 'age':'24','sex':'male','malaria_result':'negative','HIV_result':'negative','haemoglobin':'11.8'}
patient2={'patient_id':'p002', 'age':'38','sex':'female','malaria_result':'+','HIV_result':'negative','haemoglobin':'9.5'}
patient3={'patient_id':'p003', 'age':'18','sex':'male','malaria_result':'negative','HIV_result':'positive','haemoglobin':'6.8'}

patients = [patient1, patient2, patient3]
for patient in patients:
    if float(patient['haemoglobin'])< 11.0: 
       print(patient['patient_id'], 'is Anaemic')
    else:
      print(patient['patient_id'], 'is Not Anaemic')
# Out:
# p001 is Not Anaemic
# p002 is Anaemic
# p003 is Anaemic

# %% [markdown]
# FUNCTIONS

# %%
def greet():
    print ('Hi there')
    print ('Welcome to the clinic')
greet()
# Out:
# Hi there
# Welcome to the clinic

# %%
def greet(first_name, last_name):
    print (f'Hi {first_name} {last_name}')
    print ('Welcome to the clinic')
greet('Precious','Atagamen')
greet('Favour','Okoro')
# Out:
# Hi Precious Atagamen
# Welcome to the clinic
# Hi Favour Okoro
# Welcome to the clinic

# %%
def greet(name):
    print (f'Hi {name}')
    print ('Welcome to the clinic')
greet('Ebenezer')
greet('Esther')
# Out:
# Hi Ebenezer
# Welcome to the clinic
# Hi Esther
# Welcome to the clinic

# %%
def multiply(*numbers):
    total=1
    for number in numbers:
        total*= number
    return total
multiply(2,3,4,5)
# Out:
# 120
